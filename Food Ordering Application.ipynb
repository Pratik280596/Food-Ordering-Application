# %%
#Food Ordering Application

# %%
class Restaurent:
    def __init__ (self):
        self.food = {}
        self.food_id = len(self.food)+1
        self.ordered_item = []
        self.personal_details = {}
        
#Admin Functionality       
        def food_items(self):
            self.name = input("Enter Food Name:")
            self.quantity = int(input("Enter How Many Quantity You Want To Add:"))
            self.price = float(input("Enter The Price"))
            self.stock = int(input("Enter Stock In Kg"))
            self.discount = int(input("Enter Discount Value"))
            self.item = {"name":self.name , "quantity":self.quantity , "price":self.price , "stock":self.stock , "discount":self.discount}
            self.food_id = len(self.food)+1
            self.food[self.food_id] = self.item
            print("Item Added Sucessfully \n", self.food)
            
            
        def remove_items(self):
            print("Are You Sure!!! You Want To Delete Item")
            del sel.food[int(input("Enter The Food Id You Want To Delete"))]
            print("Item Is Deleted Successfully")
            print("Remaining Food Items Are:", self.food)
            
        
        def edit_food_items(self):
            f_id = int(input("Enter The Food Id You Want To Update:"))
            for i in self.food[f_id]:
                self.food[f_id] = input("Enter The"+i+ "You Want To Update:")
            print("Food Item Is Updated Sucessfully\n",self.food)
            
            
        def all_food_items(self):
            print("List Of All Food Itmes Are:")
            for i in self.food:
                print("Food id :",i,"\n")
                for j in self.food[i]:
                    print(j,":",self.food[i][j])
        
#User Functionality  
    def register(self):
        self.fullname = input("Enter Your Full Name")
        self.phone_number = int(input("Enter 10 Digit Mobile Number"))
        self.email = input("Enter Your Email")
        self.adress = input("Enter Your Full Adress")
        self.username = input("Choose Your User Name")
        self.password = input("Choose your Password")
        self.confirm_password = input("Confirm Your Password")
        self.personal_details = {"fullname":self.fullname , "phonenumber":self.phone_number , "email":self.email , "adress":self.adress , "username":self.username , "password":self.password , "confirm_password":self.confirm_password}
        
        if password != confirm_password:
            print("Password Don't Match!!!!")
            
        else:
            if len(password) <= 6:
                print("Password Is Too Short.....Please Choose Strong Password")
            
            else:
                print("Congratulations...!!! Your Account Is Created Successfully")
                
                
    def login(self):
        while True:
            user_id = input("Enter Your userid")
            password = input("Enter Your password")
            if user_id == self.username:
                if password == self.password:
                    print("Congratulation Login Sucessfully!!!!")
                    break
                else:
                    print("Incorrect Details")
            else:
                print("Incorrect Details")
    
    def place_food_item(self):
        list_of_fooditem = {1:{"name":"Tandoori Chicken" , "quantity":"4 pieces" , "price":"INR 240"},
                            2:{"name":"Vegan Burger" , "quantity":"1 Piece" , "price":"INR 320"},
                            3:{"name":"Truffle Cake" , "quantity":"500gm ", "price":"INR 900"}}
        print("Menu List")
        user_input = int(input("Select Food Item You Need To Place:"))
        if user_input == 1:
            self.ordered_item.append()
        if user_input == 2:
            self.ordered_item.append()
        if user_input == 3:
            self.ordered_item.append()
        else:
            print("Oops!!! Wrong Chooise.....Please Chooise Correct Option From Menu ")
            
    
    def order_history(self):
        for i in ordered_item:
            print(i)
